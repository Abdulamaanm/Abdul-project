# %%
import pandas as pd
import os
os.chdir("D:\data science default\pandas project")
import matplotlib.pyplot as plt

# %%
# importing pandas 
import pandas as pd 

# merging two csv files 
df = pd.concat( 
	map(pd.read_csv, ["Sales_February_2019.csv", "Sales_July_2019.csv", "Sales_June_2019.csv","Sales_April_2019.csv", "Sales_May_2019.csv","Sales_August_2019.csv","Sales_September_2019.csv","Sales_October_2019.csv","Sales_November_2019.csv","Sales_December_2019.csv","Sales_January_2019.csv"]), ignore_index=True) 
print(df) 
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        150502                    iPhone                1        700
# 1        150503     AA Batteries (4-pack)                1       3.84
# 2        150504    27in 4K Gaming Monitor                1     389.99
# 3        150505  Lightning Charging Cable                1      14.95
# 4        150506     AA Batteries (4-pack)                2       3.84
# ...         ...                       ...              ...        ...
# 171619   150497              20in Monitor                1     109.99
# 171620   150498          27in FHD Monitor                1     149.99
# 171621   150499           ThinkPad Laptop                1     999.99
# 171622   150500    AAA Batteries (4-pack)                2       2.99
# 171623   150501              Google Phone                1        600
#
#             Order Date                     Purchase Address
# 0       02/18/19 01:35    866 Spruce St, Portland, ME 04101
# ...

# %%
df.to_csv("`fullsales.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171624 entries, 0 to 171623
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          171116 non-null  object
#  1   Product           171116 non-null  object
#  2   Quantity Ordered  171116 non-null  object
#  3   Price Each        171116 non-null  object
#  4   Order Date        171116 non-null  object
#  5   Purchase Address  171116 non-null  object
# dtypes: object(6)
# memory usage: 7.9+ MB

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     171116                171116           171116     171116
# unique    163889                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         320                 20133           154773      20133
#
#         Order Date  Purchase Address
# count       171116            171116
# unique      130613            131591
# top     Order Date  Purchase Address
# freq           320               320

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        150502                    iPhone                1        700
# 1        150503     AA Batteries (4-pack)                1       3.84
# 2        150504    27in 4K Gaming Monitor                1     389.99
# 3        150505  Lightning Charging Cable                1      14.95
# 4        150506     AA Batteries (4-pack)                2       3.84
# ...         ...                       ...              ...        ...
# 171619   150497              20in Monitor                1     109.99
# 171620   150498          27in FHD Monitor                1     149.99
# 171621   150499           ThinkPad Laptop                1     999.99
# 171622   150500    AAA Batteries (4-pack)                2       2.99
# 171623   150501              Google Phone                1        600
#
#             Order Date                     Purchase Address
# 0       02/18/19 01:35    866 Spruce St, Portland, ME 04101
# ...

# %%
df.isnull().sum()
# Out:
# Order ID            508
# Product             508
# Quantity Ordered    508
# Price Each          508
# Order Date          508
# Purchase Address    508
# dtype: int64

# %%
# Out:
# 0         02
# 1         02
# 2         02
# 3         02
# 4         02
#           ..
# 171619    01
# 171620    01
# 171621    01
# 171622    01
# 171623    01
# Name: month, Length: 171116, dtype: object

# %%
df.head(5000)
# Out:
#      Order ID                     Product Quantity Ordered Price Each  \
# 0      150502                      iPhone                1        700
# 1      150503       AA Batteries (4-pack)                1       3.84
# 2      150504      27in 4K Gaming Monitor                1     389.99
# 3      150505    Lightning Charging Cable                1      14.95
# 4      150506       AA Batteries (4-pack)                2       3.84
# ...       ...                         ...              ...        ...
# 5012   155278                Google Phone                1        600
# 5013   155279            Wired Headphones                1      11.99
# 5014   155280            Wired Headphones                1      11.99
# 5015   155281          Macbook Pro Laptop                1       1700
# 5016   155282  Bose SoundSport Headphones                1      99.99
#
#           Order Date                         Purchase Address month
# ...

# %%
### clearning the data

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
# adding the coloumn

# %%
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        150502                    iPhone                1        700
# 1        150503     AA Batteries (4-pack)                1       3.84
# 2        150504    27in 4K Gaming Monitor                1     389.99
# 3        150505  Lightning Charging Cable                1      14.95
# 4        150506     AA Batteries (4-pack)                2       3.84
# ...         ...                       ...              ...        ...
# 171619   150497              20in Monitor                1     109.99
# 171620   150498          27in FHD Monitor                1     149.99
# 171621   150499           ThinkPad Laptop                1     999.99
# 171622   150500    AAA Batteries (4-pack)                2       2.99
# 171623   150501              Google Phone                1        600
#
#             Order Date                     Purchase Address month  \
# ...

# %%
# changing the datatype of two coloumn

# %%
df["Quantity Ordered"] = pd.to_numeric(df["Quantity Ordered"], errors='coerce', downcast='integer')
df.isnull().sum()
df.dropna(subset= "Quantity Ordered", inplace= True )
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# month               0
# citys               0
# dtype: int64

# %%
df["Quantity Ordered"]=  df["Quantity Ordered"].astype("int32")

# %%
# second column

# %%
df["Price Each"] = pd.to_numeric(df["Price Each"], errors='coerce')
df["Price Each"] = df["Price Each"].astype("float")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 170796 entries, 0 to 171623
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          170796 non-null  object
#  1   Product           170796 non-null  object
#  2   Quantity Ordered  170796 non-null  int32
#  3   Price Each        170796 non-null  float64
#  4   Order Date        170796 non-null  object
#  5   Purchase Address  170796 non-null  object
#  6   month             170796 non-null  object
#  7   citys             170796 non-null  object
# dtypes: float64(1), int32(1), object(6)
# memory usage: 11.1+ MB

# %%
# task 4 add city column

# %%
df["Sales"]= df["Price Each"] *df["Quantity Ordered"]
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 171619   150497              20in Monitor                 1      109.99
# 171620   150498          27in FHD Monitor                 1      149.99
# 171621   150499           ThinkPad Laptop                 1      999.99
# 171622   150500    AAA Batteries (4-pack)                 2        2.99
# 171623   150501              Google Phone                 1      600.00
#
#             Order Date                     Purchase Address month  \
# ...

# %%
df.dropna(inplace= True)
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# month               0
# citys               0
# dtype: int64

# %%
df["month"]= df["Order Date"].str[0:2]
df["month"]
df
# Out:
#        Order ID                   Product Quantity Ordered Price Each  \
# 0        150502                    iPhone                1        700
# 1        150503     AA Batteries (4-pack)                1       3.84
# 2        150504    27in 4K Gaming Monitor                1     389.99
# 3        150505  Lightning Charging Cable                1      14.95
# 4        150506     AA Batteries (4-pack)                2       3.84
# ...         ...                       ...              ...        ...
# 171619   150497              20in Monitor                1     109.99
# 171620   150498          27in FHD Monitor                1     149.99
# 171621   150499           ThinkPad Laptop                1     999.99
# 171622   150500    AAA Batteries (4-pack)                2       2.99
# 171623   150501              Google Phone                1        600
#
#             Order Date                     Purchase Address month  \
# ...

# %%
group=df.groupby("month")["Sales"].sum()
group
# Out:
# month
# 01    1822256.73
# 02    2202022.42
# 03       3207.50
# 04    3385499.82
# 05    3152606.75
# 06    2577802.26
# 07    2647775.76
# 08    2244467.88
# 09    2097560.13
# 10    3736726.88
# 11    3199603.20
# 12    4613443.34
# Name: Sales, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(group.index, group.values)
plt.xlabel("month")
plt.ylabel("sales")
plt.show()

# %%
# which city  has the highest sales

# %%
df[]

# %%
x=df.groupby("citys")["Sales"]

# %%
df["citys"]= df["Purchase Address"].apply(lambda x: x.split(",")[1])
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 171619   150497              20in Monitor                 1      109.99
# 171620   150498          27in FHD Monitor                 1      149.99
# 171621   150499           ThinkPad Laptop                 1      999.99
# 171622   150500    AAA Batteries (4-pack)                 2        2.99
# 171623   150501              Google Phone                 1      600.00
#
#             Order Date                     Purchase Address month  \
# ...

# %%
grouped= df.groupby("citys")["Sales"].sum()
plt.bar(grouped.index, grouped.values, color=  ['red', 'blue', 'green', 'orange', 'purple', "orange","green","solid","grey","])
plt.title("Sales by city")
plt.xlabel("city")
plt.ylabel("Sales")
plt.xticks(rotation=40)
plt.show()

# %%
# what time is to display the add or advsterisment to get  max likelhood of customer buying the product

# %% [markdown]
# # add time column

# %%
df["time"]= df["Order Date"].apply(lambda x: x.split(" ")[1])
df
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 0        150502                    iPhone                 1      700.00
# 1        150503     AA Batteries (4-pack)                 1        3.84
# 2        150504    27in 4K Gaming Monitor                 1      389.99
# 3        150505  Lightning Charging Cable                 1       14.95
# 4        150506     AA Batteries (4-pack)                 2        3.84
# ...         ...                       ...               ...         ...
# 171619   150497              20in Monitor                 1      109.99
# 171620   150498          27in FHD Monitor                 1      149.99
# 171621   150499           ThinkPad Laptop                 1      999.99
# 171622   150500    AAA Batteries (4-pack)                 2        2.99
# 171623   150501              Google Phone                 1      600.00
#
#             Order Date                     Purchase Address month  \
# ...

# %%
df["hour"]= df["time"].apply(lambda x: x.split(":")[0])

# %%
c=df.groupby("hour").count()

plt.plot(c.index, c.values, marker="+", color="red")
plt.ylabel("number of order")
plt.grid()
plt.xlabel("time ")
plt.show()

# %%
# here we can see that 11 am to  7 pm get the high purchased

# %%
# which city has the most number of purchased

# %%
numb= df.groupby("citys")["Quantity Ordered"].count()
numb
# Out:
# citys
#  Atlanta          13636
#  Austin            9065
#  Boston           18286
#  Dallas           13618
#  Los Angeles      27149
#  New York City    22895
#  Portland         11482
#  San Francisco    41135
#  Seattle          13530
# Name: Quantity Ordered, dtype: int64

# %%
colors = ['skyblue', 'lightgreen', 'lightcoral', 'lightgoldenrodyellow', 'lightpink']

plt.bar(numb.index, numb.values, color= colors)
plt.title(" max city get sales")
plt.xticks(rotation=40)
plt.xlabel("country")
plt.ylabel("sum of quantity")
plt.show()

# %%
product= df.groupby("Product")["Quantity Ordered"].count()
product
# Out:
# Product
# 20in Monitor                   3777
# 27in 4K Gaming Monitor         5752
# 27in FHD Monitor               6900
# 34in Ultrawide Monitor         5658
# AA Batteries (4-pack)         18902
# AAA Batteries (4-pack)        18996
# Apple Airpods Headphones      14237
# Bose SoundSport Headphones    12142
# Flatscreen TV                  4441
# Google Phone                   5062
# LG Dryer                        596
# LG Washing Machine              602
# Lightning Charging Cable      19903
# Macbook Pro Laptop             4344
# ThinkPad Laptop                3784
# USB-C Charging Cable          20133
# Vareebadd Phone                1891
# Wired Headphones              17371
# iPhone                         6305
# Name: Quantity Ordered, dtype: int64

# %%
plt.plot(product.index, product. values, marker="+", color="red" ,linestyle=":")
plt.xticks(rotation="vertical")
plt.xlabel("count of product sold")
plt.ylabel("name")
plt.show()
